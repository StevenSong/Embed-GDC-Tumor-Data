# %%
import io
import requests
import pandas as pd

GDC_BASE = "https://api.gdc.cancer.gov"

# %%
file_filter = {
    "op": "and",
    "content": [
        {"op": "in", "content": {"field": "cases.project.program.name", "value": ["TCGA"]}},
        {"op": "in", "content": {"field": "cases.samples.sample_type", "value": ["primary tumor"]}},
        {"op": "in", "content": {"field": "files.experimental_strategy", "value": ["RNA-Seq"]}},
        {"op": "in", "content": {"field": "files.data_format", "value": ["tsv"]}},
        {"op": "in", "content": {"field": "files.access", "value": ["open"]}},
    ],
}
resp = requests.post(
    f"{GDC_BASE}/files",
    json={
        "filters": file_filter,
        "fields": ",".join(["file_name", "cases.submitter_id", "experimental_strategy", "data_format", "md5sum"]),
        "format": "TSV",
        "size": "100000",
    },
)
resp.raise_for_status()
df = pd.read_csv(io.StringIO(resp.text), sep="\t")

# %%
df
# Out:
#       cases.0.submitter_id data_format experimental_strategy  \
# 0             TCGA-44-6147         TSV               RNA-Seq
# 1             TCGA-38-4631         TSV               RNA-Seq
# 2             TCGA-44-6147         TSV               RNA-Seq
# 3             TCGA-50-6597         TSV               RNA-Seq
# 4             TCGA-55-8511         TSV               RNA-Seq
# ...                    ...         ...                   ...
# 10152         TCGA-BP-5176         TSV               RNA-Seq
# 10153         TCGA-B0-5701         TSV               RNA-Seq
# 10154         TCGA-AK-3428         TSV               RNA-Seq
# 10155         TCGA-BP-5198         TSV               RNA-Seq
# 10156         TCGA-B8-5159         TSV               RNA-Seq
#
#                                                file_name  \
# 0      9a5e0fa6-a785-4d8e-bca5-43e02a3965bf.rna_seq.a...
# 1      f48a9d85-c3c7-40bc-9215-760ba3b8fa60.rna_seq.a...
# 2      ee030015-242a-4dd1-b43c-2c97d5d365d9.rna_seq.a...
# 3      555b77b9-d686-4f0e-a099-25bd5715a5e9.rna_seq.a...
# 4      27e24fc6-af40-4152-8424-a9d365c717d9.rna_seq.a...
# ...                                                  ...
# 10152  6749ec3d-aae3-4d53-b0d3-5732e48e720a.rna_seq.a...
# 10153  6740a692-f136-4f79-9a7f-d1f5114a247e.rna_seq.a...
# 10154  acc65c02-8a2b-4cd1-8a02-5187da1df978.rna_seq.a...
# 10155  0f7c2f99-0524-4b94-840f-abac69f702e6.rna_seq.a...
# 10156  4e586300-3127-4e57-9b8b-4d1178598974.rna_seq.a...
#
#                                          id                            md5sum
# 0      9a64a124-9787-4378-ba01-b79aa183f25f  01b80d4c9a15f3697ce563666de5de0a
# 1      cab5b00a-9cf2-4e1f-b2f3-93d27b73631e  5154d3e19c898832db7d8d0e19b736de
# 2      9a6d8661-241e-4a3e-a6fa-e2eb1962b758  287e77385c1a01c4a57e648ed0dbaba6
# 3      f6582ef5-5f6d-41d7-850a-614257c9e3b2  5973bc51a6a328042482da09d2d9465d
# 4      4b2e6f07-59e6-47c0-85ea-1e73f3354a01  c0062d3812c06633f6f9b9372e354ce8
# ...                                     ...                               ...
# 10152  c876a9c8-43b4-47ed-ba9d-727439ab8ef5  ff5073095eb0b395995bd935a5ea8e0e
# 10153  f478aca9-1fb9-4ef3-9c03-1bd592b2b1f7  a9c26c11ea77a45c7c95279d4b7be13f
# 10154  977c19ab-f472-4956-869f-e640960f1351  8ea446815f54633e09f3375405c70f15
# 10155  9315dffd-edea-4710-92a8-810998e08cb1  379be859d00826f3ba1df9493267def4
# 10156  577d7013-8d37-427c-82b0-24e46b891a34  4a20563fb736cf90536d9a1babe34250
#
# [10157 rows x 6 columns]

# %%
resp = requests.post(
    f"{GDC_BASE}/files",
    json={
        "filters": file_filter,
        "return_type": "manifest",
    },
)
resp.raise_for_status()

# %%
with open("../manifests/tcga-primary-tumor-rna-seq.txt", "w") as f:
    f.write(resp.text)
